# %%
# !pip install sqldf
# !pip install seaborn

# %%
# Makespan alpha_mkp = 1, alpha_cost = 0

import matplotlib.pyplot as plt
import pandas as pd
import sqldf
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")

colorGRASP = (0.229, # redness
              0.245, # greenness
              0.249, # blueness
              0.3 # transparency
             ) 

colorExact = (0.15, # redness
              0.3, # greenness
              0.74, # blueness
              0.3 # transparency
             )

plotdataMks = pd.DataFrame({
    "Exact": [18.00, 21.00, 12.00, 10.00, 10.00, 18.00, 13.00, 15.00, 16.00, 5.00, 8.00, 8.00, 8.00, 11.00, 15.00],
    "Greedy": [18.00, 23.00, 13.00, 16.00, 36.00, 38.00, 16.00, 18.00, 42.00, 5.00, 13.00, 13.00, 8.00, 22.00, 22.00],
    "Multi-start": [18.00, 21.00, 12.00, 11.00, 16.00, 27.00, 13.00, 15.00, 16.00, 5.00, 8.00, 8.00, 8.00, 14.00, 20.00],
    "GRASP": [18.00, 21.00, 12.00, 10.00, 13.00, 19.00, 13.00, 15.00, 16.00, 5.00, 8.00, 8.00, 8.00, 14.00, 20.00]},    
    index = ["Syn_7_A", "Syn_7_B", "Syn_7_C","Syn_11_A", "Syn_11_B", "Syn_11_C", "Syn_12_A", "Syn_12_B", "Syn_12_C", "Syn_13_A", "Syn_13_B", "Syn_13_C","Syn_22_A", "Syn_22_B", "Syn_22_C"])

plot = plotdataMks.plot(kind="bar",
                        width=0.7, 
                        figsize=(15, 8), 
                        color =['black', 'slategray', 'white', colorGRASP],
                        edgecolor='black')

# Define uma lista de hachuras
hatches = ['/', '\\', '|', '-']
# hatches = ['/','/','/','/']

# Aplicar hachuras a cada barra
for i, thisbar in enumerate(plot.containers):
    for j, patch in enumerate(thisbar.get_children()):
        patch.set_hatch(hatches[i % len(hatches)])

plt.title(r'$\alpha_t$ = 1, $\alpha_b$ = 0', fontsize=20)
plt.xlabel("Workflow Instance", fontsize = 20)
plt.ylabel("Makespan (in seconds)", fontsize = 20)

sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
#sns.set_context("poster")
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)
# plt.savefig("./ToyMakespan10.jpg",bbox_inches='tight')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
# Makespan alpha_mkp = 0, alpha_cost = 1

import matplotlib.pyplot as plt
import pandas as pd
import sqldf
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")

colorGRASP = (0.229, # redness
              0.245, # greenness
              0.249, # blueness
              0.3 # transparency
             )

colorExact = (0.15, # redness
              0.3, # greenness
              0.74, # blueness
              0.3 # transparency
             )

plotdataMks = pd.DataFrame({
    "Exact": [18.00, 21.00, 21.00, 13.00, 19.00, 46.00, 25.00, 28.00, 28.00, 5.00, 11.00, 15.00, 8.00, 14.00, 20.00],
    "Greedy": [18.00, 26.00, 26.00, 17.00, 37.00, 47.00, 25.00, 29.00, 33.00, 5.00, 16.00, 25.00, 8.00, 22.00, 22.00],
    "Multi-start": [18.00, 21.00, 21.00, 13.00, 19.00, 46.00, 25.00, 28.00, 28.00, 5.00, 11.00, 15.00, 8.00, 14.00, 20.00],
    "GRASP": [18.00, 21.00, 21.00, 13.00, 19.00, 46.00, 25.00, 28.00, 28.00, 5.00, 11.00, 15.00, 8.00, 14.00, 20.00]},
    index=["Syn_7_A", "Syn_7_B", "Syn_7_C","Syn_11_A", "Syn_11_B", "Syn_11_C", "Syn_12_A", "Syn_12_B", "Syn_12_C", "Syn_13_A", "Syn_13_B", "Syn_13_C","Syn_22_A", "Syn_22_B", "Syn_22_C"])


# hatch=['/','/','/','/']
plot = plotdataMks.plot(
    kind="bar",
    width = 0.7, 
    figsize=(15, 8), 
    color=['black', 'slategray', 'white', colorGRASP],
    edgecolor='black')

# Define uma lista de hachuras
hatches = ['/', '\\', '|', '-']
# hatches = ['/','/','/','/']

# Aplicar hachuras a cada barra
for i, thisbar in enumerate(plot.containers):
    for j, patch in enumerate(thisbar.get_children()):
        patch.set_hatch(hatches[i % len(hatches)])

plt.title(r'$\alpha_t$ = 0, $\alpha_b$ = 1',fontsize=20)
plt.xlabel("Workflow Instance", fontsize = 20)
plt.ylabel("Makespan (in seconds)", fontsize = 20)
sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
#sns.set_context("poster")
plt.xticks(rotation=90,fontsize = 20)
plt.yticks(fontsize = 20)
# plt.savefig("/users/daniel/Downloads/ToyMakespan01.jpg",bbox_inches='tight')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
# Makespan alpha_mkp = 0.5, alpha_cost = 0.5

import matplotlib.pyplot as plt
import pandas as pd
import sqldf
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")

colorGRASP = (0.229, # redness
              0.245, # greenness
              0.249, # blueness
              0.3 # transparency
             )

colorExact = (0.15, # redness
              0.3, # greenness
              0.74, # blueness
              0.3 # transparency
             ) 

plotdataMks = pd.DataFrame({
    "Exact": [18.00, 21.00, 12.00, 10.00, 10.00, 18.00, 13.00, 15.00, 16.00, 5.00, 8.00, 8.00, 8.00, 11.00, 15.00],
    "Greedy": [18.00, 23.00, 13.00, 17.00, 37.00, 38.00, 16.00, 18.00, 42.00, 5.00, 13.00, 13.00, 8.00, 22.00, 22.00],
    "Multi-start": [18.00, 21.00, 12.00, 11.00, 16.00, 27.00, 13.00, 15.00, 16.00, 5.00, 8.00, 8.00, 8.00, 14.00, 20.00],
    "GRASP": [18.00, 21.00, 12.00, 10.00, 13.00, 19.00, 13.00, 15.00, 16.00, 5.00, 8.00, 8.00, 8.00, 14.00, 20.00]},
    index=["Syn_7_A", "Syn_7_B", "Syn_7_C","Syn_11_A", "Syn_11_B", "Syn_11_C", "Syn_12_A", "Syn_12_B", "Syn_12_C", "Syn_13_A", "Syn_13_B", "Syn_13_C","Syn_22_A", "Syn_22_B", "Syn_22_C"])

plot = plotdataMks.plot(
    kind="bar",
    width = 0.7,
    figsize=(15, 8),
    color =['black', 'slategray', 'white', colorGRASP], 
    edgecolor='black')

# Define uma lista de hachuras
hatches = ['/', '\\', '|', '-']
# hatches = ['/','/','/','/']

# Aplicar hachuras a cada barra
for i, thisbar in enumerate(plot.containers):
    for j, patch in enumerate(thisbar.get_children()):
        patch.set_hatch(hatches[i % len(hatches)])

plt.title(r'$\alpha_t$ = 0.5, $\alpha_b$ = 0.5',fontsize=20)
plt.xlabel("Workflow Instance", fontsize = 20)
plt.ylabel("Makespan (in seconds)", fontsize = 20)
sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
#sns.set_context("poster")
plt.xticks(rotation=90,fontsize = 20)
plt.yticks(fontsize = 20)
# plt.savefig("/users/daniel/Downloads/ToyMakespan55.jpg",bbox_inches='tight')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
# Cost alpha_mkp = 1, alpha_cost = 0

import matplotlib.pyplot as plt
import pandas as pd
import sqldf
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")

colorGRASP = (0.229, # redness
              0.245, # greenness
              0.249, # blueness
              0.3 # transparency
             )

colorExact = (0.15, # redness
              0.3, # greenness
              0.74, # blueness
              0.3 # transparency
             )

plotdataMks = pd.DataFrame({
    "Exact": [0.09, 0.11, 0.10, 0.06, 0.12, 0.19, 0.10, 0.12, 0.11, 0.01, 0.02, 0.03, 0.01, 0.02, 0.03],
    "Greedy": [0.09, 0.13, 0.10, 0.10, 0.22, 0.23, 0.10, 0.11, 0.24, 0.01, 0.04, 0.05, 0.01, 0.02, 0.02],
    "Multi-start": [0.09, 0.11, 0.10, 0.07, 0.10, 0.16, 0.10, 0.12, 0.11, 0.01, 0.02, 0.03, 0.01, 0.01, 0.02],
    "GRASP": [0.09, 0.11, 0.10, 0.06, 0.11, 0.18, 0.10, 0.12, 0.11, 0.01, 0.02, 0.03, 0.01, 0.01, 0.02]},
    index=["Syn_7_A", "Syn_7_B", "Syn_7_C","Syn_11_A", "Syn_11_B", "Syn_11_C", "Syn_12_A", "Syn_12_B", "Syn_12_C", "Syn_13_A", "Syn_13_B", "Syn_13_C","Syn_22_A", "Syn_22_B", "Syn_22_C"])

plot = plotdataMks.plot(
    kind="bar",
    width = 0.7,
    figsize=(15, 8), 
    color=['black','slategray','white',colorGRASP],
    edgecolor='black')

# Define uma lista de hachuras
hatches = ['/', '\\', '|', '-']
# hatches = ['/','/','/','/']

# Aplicar hachuras a cada barra
for i, thisbar in enumerate(plot.containers):
    for j, patch in enumerate(thisbar.get_children()):
        patch.set_hatch(hatches[i % len(hatches)])

plt.title(r'$\alpha_t$ = 1, $\alpha_b$ = 0',fontsize=20)
plt.xlabel("Workflow Instance", fontsize = 20)
plt.ylabel("Cost (in US$)", fontsize = 20)

sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
#sns.set_context("poster")
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)
# plt.savefig("/users/daniel/Downloads/ToyCost10.jpg",bbox_inches='tight')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
# Cost alpha_mkp = 0, alpha_cost = 1

import matplotlib.pyplot as plt
import pandas as pd
import sqldf
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")

colorGRASP = (0.229, # redness
              0.245, # greenness
              0.249, # blueness
              0.3 # transparency
             )

colorExact = (0.15, # redness
              0.3, # greenness
              0.74, # blueness
              0.3 # transparency
             )

plotdataMks = pd.DataFrame({
    "Exact": [0.09, 0.11, 0.06, 0.01, 0.02, 0.05, 0.08, 0.08, 0.08, 0.01, 0.01, 0.02, 0.01, 0.01, 0.02],
    "Greedy": [0.09, 0.13, 0.08, 0.02, 0.04, 0.05, 0.08, 0.09, 0.26, 0.01, 0.02, 0.03, 0.01, 0.02, 0.02],
    "Multi-start": [0.09, 0.11, 0.06, 0.01, 0.02, 0.05, 0.08, 0.08, 0.08, 0.01, 0.01, 0.02, 0.01, 0.01, 0.02],
    "GRASP": [0.09, 0.11, 0.06, 0.01, 0.02, 0.05, 0.08, 0.08, 0.08, 0.01, 0.01, 0.02, 0.01, 0.01, 0.02]},
    index=["Syn_7_A", "Syn_7_B", "Syn_7_C","Syn_11_A", "Syn_11_B", "Syn_11_C", "Syn_12_A", "Syn_12_B", "Syn_12_C", "Syn_13_A", "Syn_13_B", "Syn_13_C","Syn_22_A", "Syn_22_B", "Syn_22_C"])

plot = plotdataMks.plot(
    kind="bar",
    width = 0.7,
    figsize=(15, 8),
    color =['black', 'slategray', 'white', colorGRASP],
    edgecolor='black')

# Define uma lista de hachuras
hatches = ['/', '\\', '|', '-']
# hatches = ['/','/','/','/']

# Aplicar hachuras a cada barra
for i, thisbar in enumerate(plot.containers):
    for j, patch in enumerate(thisbar.get_children()):
        patch.set_hatch(hatches[i % len(hatches)])

plt.title(r'$\alpha_t$ = 0, $\alpha_b$ = 1',fontsize=20)
plt.xlabel("Workflow Instance", fontsize = 20)
plt.ylabel("Cost (in US$)", fontsize = 20)
sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
#sns.set_context("poster")
plt.xticks(rotation=90,fontsize = 20)
plt.yticks(fontsize = 20)
# plt.savefig("/users/daniel/Downloads/ToyCost01.jpg",bbox_inches='tight')
plot.plot
# Out:
# <bound method Axes.plot of <Axes: title={'center': '$\\alpha_t$ = 0, $\\alpha_b$ = 1'}, xlabel='Workflow Instance', ylabel='Cost (in US$)'>>

# %%
# Cost alpha_mkp = 0.5, alpha_cost = 0.5

import matplotlib.pyplot as plt
import pandas as pd
import sqldf
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")

colorGRASP = (0.229, # redness
              0.245, # greenness
              0.249, # blueness
              0.3 # transparency
             )

colorExact = (0.15, # redness
              0.3, # greenness
              0.74, # blueness
              0.3 # transparency
             )
plotdataMks = pd.DataFrame({
    "Exact":[0.09, 0.11, 0.10, 0.06, 0.11, 0.19, 0.10, 0.12, 0.11, 0.01, 0.02, 0.03, 0.01, 0.02, 0.03],
    "Greedy":[0.09, 0.13, 0.10, 0.02, 0.04, 0.23, 0.10, 0.11, 0.24, 0.01, 0.04, 0.05, 0.01, 0.02, 0.02],
    "Multi-start":[0.09, 0.11, 0.10, 0.07, 0.10, 0.16, 0.10, 0.12, 0.11, 0.01, 0.02, 0.03, 0.01, 0.01, 0.02],
    "GRASP":[0.09, 0.11, 0.10, 0.06, 0.11, 0.18, 0.10, 0.12, 0.11, 0.01, 0.02, 0.03, 0.01, 0.01, 0.02]},
    index=["Syn_7_A", "Syn_7_B", "Syn_7_C","Syn_11_A", "Syn_11_B", "Syn_11_C", "Syn_12_A", "Syn_12_B", "Syn_12_C", "Syn_13_A", "Syn_13_B", "Syn_13_C","Syn_22_A", "Syn_22_B", "Syn_22_C"])

plot = plotdataMks.plot(
    kind="bar",
    width=0.7, 
    figsize=(15, 8), 
    color=['black', 'slategray', 'white', colorGRASP],
    edgecolor='black')

# Define uma lista de hachuras
hatches = ['/', '\\', '|', '-']
# hatches = ['/','/','/','/']

# Aplicar hachuras a cada barra
for i, thisbar in enumerate(plot.containers):
    for j, patch in enumerate(thisbar.get_children()):
        patch.set_hatch(hatches[i % len(hatches)])

plt.title(r'$\alpha_t$ = 0.5, $\alpha_b$ = 0.5', fontsize=20)
plt.xlabel("Workflow Instance", fontsize = 20)
plt.ylabel("Cost (in US$)", fontsize=20)
sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
#sns.set_context("poster")
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)
# plt.savefig("/users/daniel/Downloads/ToyCost55.jpg",bbox_inches='tight')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>
