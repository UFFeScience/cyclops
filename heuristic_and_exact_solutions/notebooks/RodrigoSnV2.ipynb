# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [141.65,141.00, 232.8,243, 403.05,418,126.5,131,251.5,262,518.2,547]
error = [0.812727700887249,0, 10.476037820715074,0, 15.398137276272976,0,4.616902584383193,0,10.772772696894117,0,29.55209494755784,0]

# %%
fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.9,$\alpha_b$ = 0.05, $\alpha_s$ = 0.05',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Makespan (in seconds)", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/09_05_05_Makespan.png')
plt.show()

# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [82.77199999999996,83.340,137.82549999999995,144,240.06400000000002, 249.8,71.49499999999998, 74.5,144.95649999999998, 154, 304.704, 325  ]
error = [1.1502521462705524,0,6.46724091092951,0,010.080320274778238,0,3.175402999703559,0,9.95652511514036,0, 21.132057562909157, 0]


fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.9,$\alpha_b$ = 0.05, $\alpha_s$ = 0.05',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Financial Cost (in US$)", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/09_05_05_Cost.png')
plt.show()

# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [0.1887597,0.263566,0.16689520000000002,0.228311,0.17894115000000002,0.245495,0.20161300000000004,0.245495,0.17941834999999995,0.276744,0.16503180000000003,0.253731]
error = [0.07708066718096802,0,0.06319301210085611,0,0.06846029124688188,0,0.10756254445425545,0,0.09985985368519698,0,0.09100621927943627,0]


fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.9,$\alpha_b$ = 0.05, $\alpha_s$ = 0.05',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Confidentiality Penalty", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/09_05_05_Security.png')
plt.show()

# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [246.95,141.00, 348.2,243, 560.25,418,224.5,131,336.45,262,607.65,547]
error = [108.71327571087845,0, 115.20900915064621,0, 145.9639014493508,0,95.92897591996191,0,76.82754097738375,0,62.504968223586665,0]


fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.05,$\alpha_b$ = 0.9, $\alpha_s$ = 0.05',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Makespan (in seconds)", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/05_09_05_Makespan.png')
plt.show()

# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [69.70299999999999,83.340,126.70399999999995,144,217.45850000000002, 249.8,46.13500000000001, 74.5,109.53600000000002, 154, 263.56, 325  ]
error = [13.991501593542607,0,17.913913851352664,0,33.23904319273378,0,29.194214008583053,0,46.29708941630189,0, 63.34254643976421, 0]


fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.05,$\alpha_b$ = 0.9, $\alpha_s$ = 0.05',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Financial Cost (in US$)", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/05_09_05_Cost.png')
plt.show()

# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [0.1926357,0.263566,0.16392715000000002,0.228311,0.17162139999999998,0.245495,0.15591400000000002,0.245495,0.15732539999999995,0.276744,0.15309160000000002,0.253731]
error = [0.07281857250086109,0,0.06899467022304578,0,0.07597637451027994,0,0.15444872916619493,0,0.12252566275785914,0,0.10325662605597355,0]


fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.05,$\alpha_b$ = 0.9, $\alpha_s$ = 0.05',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Confidentiality Penalty", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/05_09_05_Security.png')
plt.show()

# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [157.3,141, 243.8,243, 411.6,418,156.85,131,275.55,262,551.4,547]
error = [16.914957566416895,0, 3.4883263970895237,0, 6.6995679357937545,0,26.543459894254454,0,14.848267664329699,0,5.344943503221674,0]


fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.05,$\alpha_b$ = 0.05, $\alpha_s$ = 0.9',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Makespan (in seconds)", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/05_05_09_Makespan.png')
plt.show()

# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [80.03199999999998,83,140.15099999999995,144,244.2135, 249.8,51.82750000000001, 74.5,128.4815, 154, 270.6055, 325  ]
error = [4.24176552120012,0,5.785811956847555,0,5.955750228936214,0,23.463060973861825,0,26.861538396004036,0, 56.114684022052, 0]


fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.05,$\alpha_b$ = 0.05, $\alpha_s$ = 0.9',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Financial Cost (in US$)", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/05_05_09_Cost.png')
plt.show()

# %%
# Create lists for the plot
materials = ['CS_030_C','CS_030_H', 'CS_050_C','CS_050_H', 'CS_100_C','CS_100_H','M_025_C','M_025_H','M_050_C','M_050_H','M_100_C','M_100_H']
x_pos = np.arange(len(materials))
CTEs = [0.17054249999999999,0.263566,0.15570810000000002,0.228311,0.17376095,0.245495,0.16935500000000003,0.245495,0.16709274999999996,0.276744,0.15666270000000002,0.253731]
error = [0.09544009723519335,0,0.0745007873988061,0,0.07362678030193189,0,0.14065855413581838,0,0.11250246414698986,0,0.09959024471836161,0]


fig, ax = plt.subplots( figsize=(20, 10))
ax.bar(x_pos, CTEs, yerr=error, align='center', alpha=0.96, ecolor='black', color=['gray','black'], capsize=30)
ax.set_ylabel('Coefficient of Thermal Expansion ($\degree C^{-1}$)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)
plt.title(r'$\alpha_t$ = 0.05,$\alpha_b$ = 0.05, $\alpha_s$ = 0.9',fontsize=30)
plt.xlabel("Workflow Instance", fontsize = 30)
#sns.set_context("notebook", font_scale=2.5, rc={"lines.linewidth": 1.5})
plt.ylabel("Confidentiality Penalty", fontsize = 30)
plt.xticks(rotation=90,fontsize = 20)
sns.set_context("poster")
plt.yticks(fontsize = 30)

# Save the figure and show
plt.tight_layout()
plt.savefig('/users/daniel/Downloads/05_05_09_Security.png')
plt.show()
